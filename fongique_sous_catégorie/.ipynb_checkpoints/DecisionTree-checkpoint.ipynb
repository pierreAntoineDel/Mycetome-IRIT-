# %% [markdown]
# # FUNGUS MYCETOMA CLASSIFICATION

# %% [markdown]
# ## Method : decision tree

# %% [markdown]
# <p> Reminders about data :
#     <ul>
#         <li> FM : fungus / BM : bacterial
#         <li> label = type + n°patient + _ + n°grain
#     </ul>
# </p>

# %%
# %run dataManagementPart2.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, average_precision_score
from sklearn.decomposition import PCA
from scikitplot.metrics import plot_confusion_matrix, plot_roc_curve

# %% [markdown]
# ##### 1) Getting data

# %%
file1 = './Data/radiomics_features_set1.csv'
file2 = './Data/radiomics_features_set2.csv'

# %%
data = readCSV(file1,file2)

# %%
# fungus mycetoma type
y = getLabels(data)[1]

# associated data
X = getData(data)[1]
# Out:
# (206, 102) (37, 102) (16, 102)

# %% [markdown]
# ##### 2) Balancing data

# %%
nb1 = y.count(1)
nb2 = y.count(2)
print("Number of type 1 :",nb1)
print("Number of type 2 :",nb2)

balanced_y = []
balanced_X = []

cpt = 0
for i in range(len(y)):
    if y[i] == 1 and cpt != nb2:
        balanced_y.append(y[i])
        balanced_X.append(data.iloc[i])
        cpt += 1
    elif y[i] == 2:
        balanced_y.append(y[i])
        balanced_X.append(X.iloc[i,:])

y = balanced_y 
X = pd.DataFrame(balanced_X,index=[i for i in range(nb2*2)],columns=X.columns)

nb1_end = y.count(1)
nb2_end = y.count(2)
print("Number of type 1 :",nb1_end)
print("Number of type 2 :",nb2_end)
# Out:
# Number of type 1 : 166
# Number of type 2 : 111
# Number of type 1 : 111
# Number of type 2 : 111

# %% [markdown]
# ##### 3) Preprocessing the data (to remove the negative numbers)

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ##### 4) Studying the number of features to keep for the PCA

# %%
pca = PCA(n_components=102) #creating a PCA for a test (we have 102 features)
pca.fit(X)

variance = pca.explained_variance_ratio_ #calculate variance ratios 
var = np.cumsum(np.round(pca.explained_variance_ratio_, decimals=3)*100)
var #cumulative sum of variance explained with [n] features
# Out:
# array([37.9, 60.2, 74.3, 81. , 85.6, 88.3, 90.4, 91.8, 93.1, 94. , 94.8,
#        95.5, 96.1, 96.6, 97. , 97.4, 97.7, 98. , 98.3, 98.5, 98.7, 98.9,
#        99. , 99.1, 99.2, 99.3, 99.4, 99.5, 99.6, 99.6, 99.6, 99.6, 99.6,
#        99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6,
#        99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6,
#        99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6,
#        99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6,
#        99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6,
#        99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6, 99.6,
#        99.6, 99.6, 99.6])

# %%
plt.ylabel('% Variance Explained')
plt.xlabel('number of Features')
plt.title('PCA Analysis')
plt.xlim(0,40)
plt.style.context('seaborn-whitegrid')
plt.plot(var)

# %% [markdown]
# <p> According to the curve, we need to keep between 10 and 20 features for the PCA. </p>

# %% [markdown]
# ##### 5) Defining training and testing data

# %%
pca_tree = PCA(n_components=10) #creating the PCA for the following decision tree 
pca_tree.fit(X)

X = pca_tree.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X,y)
print("Training data dimension :",X_train.shape)
print("Test data dimension :",X_test.shape)
# Out:
# Training data dimension : (166, 10)
# Test data dimension : (56, 10)

# %% [markdown]
# ##### 6) Learning

# %% [markdown]
# - Decision Tree Classifier

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

fig = plt.figure(figsize=(50,50))
_ = tree.plot_tree(clf, filled=True)

# %% [markdown]
# - Decision Tree Regressor

# %%
rgr = tree.DecisionTreeRegressor()
rgr = rgr.fit(X_train, y_train)

fig = plt.figure(figsize=(50,50))
_ = tree.plot_tree(rgr, filled=True)

# %% [markdown]
# ##### 5) Testing

# %%
y_clf = clf.predict(X_test)
y_rgr = rgr.predict(X_test)

# %% [markdown]
# - cross-validation

# %%
cv_clf = cross_val_score(clf, X, y)
print("---> with classifier :", cv_clf)
# Out:
# ---> with classifier : [0.66666667 0.73333333 0.52272727 0.68181818 0.75      ]

# %%
cv_rgr = cross_val_score(rgr, X, y)
print("---> with regressor :", cv_rgr)
# Out:
# ---> with regressor : [-0.01851852 -1.95714286 -0.19166667 -0.57473684  0.        ]

# %% [markdown]
# - confusion matrix

# %%
print("---> with classifier :")
plot_confusion_matrix(y_test,y_clf)
# Out:
# ---> with classifier :
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
print("---> with regressor :")
plot_confusion_matrix(y_test,y_rgr)
# Out:
# ---> with regressor :
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# - precision, recall, F-measure

# %%
f1_clf = f1_score(y_test,y_clf)
print("---> with classifier :",f1_clf)
# Out:
# ---> with classifier : 0.6909090909090909

# %%
f1_rgr = f1_score(y_test,y_rgr)
print("---> with regressor :",f1_rgr)
# Out:
# ---> with regressor : 0.6909090909090909

# %% [markdown]
# - roc curves

# %%
print("---> with classifier :")

fpr,tpr,thresholds = roc_curve(y_test,y_clf,pos_label=2)

plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')

AUROC = np.round(roc_auc_score(y_test, y_clf), 2)

plt.title(f'Logistic Regression Model ROC curve; AUROC: {AUROC}');
plt.show()
# Out:
# ---> with classifier :

# %%
print("---> with regressor :")

fpr,tpr,thresholds = roc_curve(y_test,y_rgr,pos_label=2)

plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')

AUROC = np.round(roc_auc_score(y_test, y_rgr), 2)

plt.title(f'Logistic Regression Model ROC curve; AUROC: {AUROC}');
plt.show()
# Out:
# ---> with regressor :
